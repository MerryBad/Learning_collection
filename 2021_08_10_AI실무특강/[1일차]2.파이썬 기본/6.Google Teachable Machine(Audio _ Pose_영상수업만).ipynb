# %% [markdown]
# #Google Teachable Machine
# - 누구나 빠르고 쉽게 기계학습 모델을 만들 수 있는 웹기반 도구

# %% [markdown]
# [Teachabel Machine 홈페이지](https://teachablemachine.withgoogle.com)

# %% [markdown]
# ## Teachable Machine 홈페이지에서 'New Project'을 선택하거나 'Get Started'  버튼 클릭
# - Image Project
# - Audio Project
# - Pose Project

# %% [markdown]
# https://laurencemoroney.com/datasets.html

# %% [markdown]
# https://blog.naver.com/roboholic84/221870792611

# %% [markdown]
# #  Audio Classification
# - 레이블을 가진 오디오 데이터를 훈련 데이터로 사용하여 분류 모델을 구축하고, 이 분류 모델을 이용하여 새로운 오디오 데이터의 레이블을 판별하는 태스크
# - 사람 목소리와 강아지 소리 분류(이진 분류)
# - 바이올린, 첼로, 피아노 세 종류의 악기 소리 데이터 분류(다중 분류)

# %% [markdown]
# # Pose Classification
