# %% [markdown]
# # 1.구글 코랩 설명 및 설치방법
#
#
#
# 1. 데이터 과학과 머신러닝에 사용되는 가장 유명한 도구으로는 주피터 노트북이 있습니다.
# 2. 이것은 노트북이라 불리는 파일을 웹 브라우저로 실행하며 프로그래밍할 수 있는 것인데  구글에서도 이와같은 것을 만들었다 그것이 바로 구글 코랩입니다.
# 3. 구글 코랩은 구글 드라이브 내에서 주피터 노트북같은 기능을 사용할 수 있게 만든 것입니다.
#
#
# 사용 방법은 다음과 같습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 코드를 위 아래에 추가하고싶다면 저렇게 마우스를 선에 갖다대면 +코드, +텍스트가 나온다 +코드를 이용하여
#
# 코드를 추가해주면 된다.
#
# ​
#
# 실행할 때, 화살표 말고 컨트롤 엔터, 시프트 엔터로 실행이 가능한데
#
# ​
#
# 컨트롤 엔터는 현재 코드를 실행한 이후에도 현재 코드에 머무르는 것이고
#
# 시프트 엔터는 현재 코드를 실행한 이후에 다음 코드자리로 넘어가는 것이다.
# [출처] 구글 코랩 사용법|작성자 KDeveloper

# %% [markdown]
# # 2.구글 코랩 사용법
# * shift + Enter 키를 누르면 셀의 코드가 실행되고 커서가 다음셀로 이동합니다.
# * ctrl + Enter 키를 누르면 셀의 코드가 실행되고 커서가 종료 됩니다.
# * Enter키를 누르면 다시 편집상태가 됩니다.
# * ESC키를 누르고
#     * a 키를 누르면 위에 셀이 추가 됩니다.
#     * b 키를 누르면 아래에 셀이 추가 됩니다.
#     * dd키를 누르면 셀이 삭제 됩니다.

# %% [markdown]
# # 3.텍스트 셀(마크다운)이란?
# * 코드와 함께 설명 문서를 만들 수 있습니다.
# * 목차로도 정리가 되며 해당 목차를 클릭하면 해당 셀로 이동합니다.
# * 코드와 함께 문서화를 할수 있는 주피터 노트북 스타일의 `문법`입니다.
#
#
# ```
# 여러줄의 설명을
# 줄바꿈으로 쓰고자 할 때
# ```
#
# ```
# (내용 입력)
# ```

# %% [markdown]
# # 4.구글 드라이브 마운트 하는 방법

# %%
#1) 구글 드라이브 연동하기
#2) 구글 드라이브에 데이터를 올린 후 사용할 경우에만 실행
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#3) 구글 드라이브에서 파일 읽어오는 코드
import pandas as pd

# 경로 설정
#chat_dir = '/content/gdrive/My Drive/Colab Notebooks/충북대 AI특강/실습 파일/practice_data/data/'
# !ls -al '/content/drive/My Drive/Colab Notebooks/충북대 AI특강/실습 파일/colab_train.csv' 

# 실습 디렉토리 생성 후 파일 읽어오기 연습
train = pd.read_csv("/content/drive/My Drive/Colab Notebooks/충북대 AI특강/실습 파일/colab_train.csv", parse_dates=["datetime"])
#train = pd.read_csv("/content/drive/My Drive/Colab Notebooks/충북대 AI특강/실습 파일/[2일차]1.kaggle 실습/kaggle_bike/data/bike/train.csv", parse_dates=["datetime"])
train.shape
#train.head()
# Out:
# -rw------- 1 root root 648353 Aug  1 04:09 '/content/drive/My Drive/Colab Notebooks/충북대 AI특강/실습 파일/colab_train.csv'
# (10886, 12)

# %%
import numpy as np
import matplotlib.pylab as plt

def step_function(x):
    return np.array(x > 0, dtype=np.int)

X = np.arange(-5.0, 5.0, 0.1)
Y = step_function(X)
plt.plot(X,Y)
plt.ylim(-0.1,1.1)
plt.show()

# %%
import numpy as np
import matplotlib.pylab as plt

def sigmoid(x):
    return 1 / (1+np.exp(-x))

x = np.array([-1.0,1.0,2.0,-6.0,6.0])
print(sigmoid(x))

X = np.arange(-5.0, 5.0, 0.1)
Y = sigmoid(X)

plt.plot(X,Y)
plt.ylim(-0.1,1.1)

plt.show()
# Out:
# [0.26894142 0.73105858 0.88079708 0.00247262 0.99752738]

# %%
import numpy as np
import matplotlib.pylab as plt


def relu(x):
    return np.maximum(0,x)

x = np.arange(-5.0, 5.0, 0.1)
y = relu(x)

plt.plot(x,y)
plt.ylim(-1.0, 5.5)
plt.show()

# %%
def softmax(a):
    c = np.max(a)
    exp_a = np.exp(a-c)
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a
    return y

print(softmax(3.7))
print(np.sum(softmax(1)))
# Out:
# 1.0
# 1.0
